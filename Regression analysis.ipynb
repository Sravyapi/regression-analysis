# %%
import numpy as np
import pandas as pd
from sklearn import linear_model,metrics,cross_validation
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
df = pd.read_csv('/Users/sp/Desktop/slump_test_data.csv')
X=df.iloc[:,1:8]
Y=df.iloc[:,9]
X=np.array(X)
Y=np.array(Y)
final_mse_sum_linear=0
final_r2_sum_linear=0
final_mse_sum_ridge=0
final_r2_sum_ridge=0
final_mse_sum_lasso=0
final_r2_sum_lasso=0
for i in range(0, 10):
    X_train,X_test,Y_train,Y_test=cross_validation.train_test_split(X,Y,test_size=18/103) #,shuffle=True)
    kf = KFold(n_splits=5,shuffle=True)
    kf.get_n_splits(X_train)
    best_r2_linear=0
    best_r2_lasso=0
    best_r2_ridge=0
    best_mse_linear=0
    best_mse_lasso=0
    best_mse_ridge=0
    for train_index, test_index in kf.split(X_train):
        X_train_CV, Y_train_CV,X_test_CV = X[train_index],Y[train_index], X[test_index]
        linearReg_CV = linear_model.LinearRegression()
        ridgeReg_CV = linear_model.RidgeCV(alphas=[0.1,0.5,1.0,5,10,15,20])
        lassoReg_CV = linear_model.LassoCV(alphas=[0.1,0.5,1.0,5,10,15,20]) 
        linearReg_CV.fit(X_train_CV, Y_train_CV)
        ridgeReg_CV.fit(X_train_CV,Y_train_CV)
        lassoReg_CV.fit(X_train_CV,Y_train_CV)
        linear_Pred_Y_CV = linearReg_CV.predict(X_test_CV)
        ridge_Pred_Y_CV = ridgeReg_CV.predict(X_test_CV)
        lasso_Pred_Y_CV=lassoReg_CV.predict(X_test_CV)
        #print(ridgeReg.alpha_)
        #print(lassoReg.alpha_)
        MSE_linear_CV=np.mean((linear_Pred_Y_CV - Y_test_CV)**2)
        MSE_ridge_CV=np.mean((ridge_Pred_Y_CV - Y_test_CV)**2)
        MSE_lasso_CV=np.mean((Lasso_Pred_Y_CV - Y_test_CV)**2)
        r2_linear_CV=r2_score(Y_test_CV, linear_Pred_Y_CV)
        r2_ridge_CV=r2_score(Y_test_CV, ridge_Pred_Y_CV)
        r2_lasso_CV=r2_score(Y_test_CV, lasso_Pred_Y_CV)
        if r2_linear_CV > best_r2_linear:
            best_r2_linear=r2_linear_CV
            best_mse_linear = MSE_linear_CV
            best_X_train_linear=X_train_CV
            best_Y_train_linear=Y_train_CV
        if r2_ridge_CV>best_r2_ridge:
            best_mse_ridge = MSE_ridge_CV
            best_r2_ridge=r2_ridge_CV
            best_X_train_ridge=X_train_CV
            best_Y_train_ridge=Y_train_CV
        if r2_lasso_CV>best_r2_lasso:
            best_mse_lasso= MSE_lasso_CV
            best_r2_lasso=r2_lasso_CV
            best_X_train_lasso=X_train_CV
            best_Y_train_lasso=Y_train_CV
    best_linearReg = linear_model.LinearRegression()
    best_ridgeReg = linear_model.Ridge(alpha=ridgeReg.alpha_)
    best_lassoReg = linear_model.Lasso(alpha=lassoReg.alpha_) 
    best_linearReg.fit(best_X_train_linear, best_Y_train_linear)
    best_ridgeReg.fit(best_X_train_ridge, best_Y_train_ridge)
    best_lassoReg.fit(best_X_train_lasso, best_Y_train_lasso)
    best_Y_pred_linear = best_linearReg.predict(X_test)
    best_Y_pred_ridge = best_ridgeReg.predict(X_test)
    best_Y_pred_lasso = best_lassoReg.predict(X_test)
    final_mse_linear=np.mean((best_Y_pred_linear - Y_test)**2)
    final_mse_ridge=np.mean((best_Y_pred_ridge - Y_test)**2)
    final_mse_lasso=np.mean((best_Y_pred_lasso - Y_test)**2)
    final_r2_linear=r2_score(Y_test, best_Y_pred_linear)
    final_r2_ridge=r2_score(Y_test, best_Y_pred_ridge)
    final_r2_lasso=r2_score(Y_test, best_Y_pred_lasso)
    final_mse_sum_linear=final_mse_sum_linear+final_mse_linear
    final_mse_sum_ridge=final_mse_sum_ridge+final_mse_ridge
    final_mse_sum_lasso=final_mse_sum_lasso+final_mse_lasso
    final_r2_sum_linear=final_r2_sum_linear+final_r2_linear
    final_r2_sum_ridge=final_r2_sum_ridge+final_r2_ridge
    final_r2_sum_lasso=final_r2_sum_lasso+final_r2_lasso
    fig, ax = plt.subplots()
    ax.scatter(Y_test, best_Y_pred_linear, edgecolors=(0, 0, 0))
    ax.plot([Y_test.min(), Y_test.max()], [Y_test.min(), Y_test.max()], 'k--', lw=4)
    ax.set_xlabel('Y- True values')
    ax.set_ylabel('Y- Predicted')
    plt.title('Linear '+ str(i))
    plt.show()
######################TASK2##################
alphas=np.array([0,5,10,15,20,25,30])
coefs_ridge = []
coefs_lasso = []
for a in alphas:
    ridge = linear_model.Ridge(alpha=a, fit_intercept=False)
    ridge.fit(best_X_train_ridge, best_Y_train_ridge)
    lasso.fit(best_X_train_lasso, best_Y_train_lasso)
    coefs_ridge.append(ridge.coef_)
    coefs_lasso.append(lasso.coef_)
ax = plt.gca()
for i in range (0,6):
    ax.plot(alphas,np.array(coefs_ridge).T[i])
plt.xlabel('alpha')
plt.ylabel('coefficients')
plt.title('Ridge coefficients as a function of the regularization')
plt.axis('tight')
plt.show()
ax = plt.gca()
for i in range (0,6):
    ax.plot(alphas,np.array(coefs_lasso).T[i])
plt.xlabel('alpha')
plt.ylabel('coefficients')
plt.title('Lasso coefficients as a function of the regularization')
plt.axis('tight')
plt.show()

#############################################
final_mse_avg_linear=(final_mse_sum_linear)/10
final_mse_avg_ridge=(final_mse_sum_ridge)/10
final_mse_avg_lasso=(final_mse_sum_lasso)/10
final_r2_avg_linear=(final_r2_sum_linear)/10
final_r2_avg_ridge=(final_r2_sum_ridge)/10     
final_r2_avg_lasso=(final_r2_sum_lasso)/10
print('AVG Mean squared error-  mse: linear' , final_mse_avg_linear)
print('AVG Mean squared error-  mse: ridge' , final_mse_avg_ridge)
print('AVG Mean squared error-  mse: lasso' , final_mse_avg_lasso)
print('AVG Variance score-best RSquare: linear ', final_r2_avg_linear)
print('AVG Variance score-best RSquare: ridge ', final_r2_avg_ridge)                                          
print('AVG Variance score-best RSquare: lasso ', final_r2_avg_lasso)
# Out:
# /Users/sp/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/sp/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/sp/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model,cross_validation

df = pd.read_csv('/Users/sp/Desktop/slump_test_data.csv')
X=df.iloc[:,1:8]
Y=df.iloc[:,9]
X=np.array(X)
Y=np.array(Y)
X_train,X_test,Y_train,Y_test=cross_validation.train_test_split(X,Y,test_size=18/103)

alphas=np.array([0,5,10,15,20,25,30])
coefs = []

for a in alphas:
    lasso = linear_model.Lasso(alpha=a, fit_intercept=False)
    lasso.fit(X_train, Y_train)
    coefs.append(lasso.coef_)
ax = plt.gca()
for i in range (0,6):
    ax.plot(alphas,np.array(coefs).T[i])
plt.xlabel('alpha')
plt.ylabel('coefficients')
plt.title('Lasso coefficients as a function of the regularization')
plt.axis('tight')
plt.show()
# Out:
# /Users/sp/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
# /Users/sp/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:477: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/sp/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model,cross_validation

df = pd.read_csv('/Users/sp/Desktop/slump_test_data.csv')
X=df.iloc[:,1:8]
Y=df.iloc[:,9]
X=np.array(X)
Y=np.array(Y)
X_train,X_test,Y_train,Y_test=cross_validation.train_test_split(X,Y,test_size=18/103)

alphas=np.array([0,5,10,15,20,25,30])
coefs = []

for a in alphas:
    ridge = linear_model.Ridge(alpha=a, fit_intercept=False)
    ridge.fit(X_train, Y_train)
    coefs.append(ridge.coef_)
ax = plt.gca()
for i in range (0,6):
    ax.plot(alphas,np.array(coefs).T[i])
plt.xlabel('alpha')
plt.ylabel('coefficients')
plt.title('Ridge coefficients as a function of the regularization')
plt.axis('tight')
plt.show()
